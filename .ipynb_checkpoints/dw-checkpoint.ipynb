# %%
# %logstop
# %logstart -rtq ~/.logs/dw.py append
# %matplotlib inline
import matplotlib
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %%
from static_grader import grader

# %% [markdown]
# # DW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to wrangle tabular data set and aggregate large data sets into meaningful summary statistics. We'll work with the same medical data used in the `pw` miniproject but leverage the power of Pandas to more efficiently represent and act on our data.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# !mkdir dw-data
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/201701scripts_sample.csv.gz -nc -P ./dw-data/
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/201606scripts_sample.csv.gz -nc -P ./dw-data/
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/practices.csv.gz -nc -P ./dw-data/
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/chem.csv.gz -nc -P ./dw-data/
# Out:
# mkdir: cannot create directory ‘dw-data’: File exists
# File ‘./dw-data/201701scripts_sample.csv.gz’ already there; not retrieving.
#
# File ‘./dw-data/201606scripts_sample.csv.gz’ already there; not retrieving.
#
# File ‘./dw-data/practices.csv.gz’ already there; not retrieving.
#
# File ‘./dw-data/chem.csv.gz’ already there; not retrieving.

# %% [markdown]
# ## Loading the data
#
# Similar to the `PW` miniproject, the first step is to read in the data. The data files are stored as compressed CSV files. You can load the data into a Pandas DataFrame by making use of the `gzip` package to decompress the files and Panda's `read_csv` methods to parse the data into a DataFrame. You may want to check the Pandas documentation for parsing [CSV](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) files for reference.
#
# For a description of the data set please, refer to the [PW miniproject](./pw.ipynb). **Note that all questions make use of the 2017 data only, except for Question 5 which makes use of both the 2017 and 2016 data.**

# %%
import pandas as pd
import numpy as np
import gzip

# %%
# load the 2017 data
scripts = pd.read_csv('dw-data/201701scripts_sample.csv.gz')
scripts
# Out:
#        practice   bnf_code                                  bnf_name  items  \
# 0        N85639  0106020C0                     Bisacodyl_Tab E/C 5mg      1
# 1        N85639  0106040M0          Movicol Plain_Paed Pdr Sach 6.9g      1
# 2        N85639  0301011R0        Salbutamol_Inha 100mcg (200 D) CFF      1
# 3        N85639  0304010G0      Chlorphenamine Mal_Oral Soln 2mg/5ml      1
# 4        N85639  0401020K0                          Diazepam_Tab 2mg      1
# ...         ...        ...                                       ...    ...
# 973188   H81615  239410100  Coloplast_SenSura Mio Flex B/Plt 50mm C/      1
# 973189   H81615  239410100  Coloplast_SenSura Mio Flex Clsd Bag Mini      1
# 973190   H81615  239410100  Coloplast_SenSura Mio Flex Clsd Bag Midi      1
# 973191   H81615  239607096  Dansac_Nova 1 Convex Urost Pouch Clr C/F      2
# 973192   H81615  239610096  Coloplast_SenSura Mio Urost Bag Maxi Tra      1
#
#            nic  act_cost  quantity
# ...

# %%
col_names=[ 'code', 'name', 'addr_1', 'addr_2', 'borough', 'village', 'post_code']
practices = pd.read_csv('dw-data/practices.csv.gz')
practices.columns = col_names
practices
# Out:
#          code                             name                     addr_1  \
# 0      A81002       QUEENS PARK MEDICAL CENTRE    QUEENS PARK MEDICAL CTR
# 1      A81003        VICTORIA MEDICAL PRACTICE          THE HEALTH CENTRE
# 2      A81004           WOODLANDS ROAD SURGERY           6 WOODLANDS ROAD
# 3      A81005               SPRINGWOOD SURGERY         SPRINGWOOD SURGERY
# 4      A81006  TENNANT STREET MEDICAL PRACTICE       TENNANT ST MED PRACT
# ...       ...                              ...                        ...
# 12014  Y05752             MALVERN FRAILTY UNIT     MALVERN COMM. HOSPITAL
# 12015  Y05757             VC WEST LANCS HC-UCC       ORMSKIRK DG HOSPITAL
# 12016  Y05758              VC SKELMERSDALE UCC  CONCOURSE SHOPPING CENTRE
# 12017  Y05762           WEST MERTON ACCESS HUB   THE NELSON HEALTH CENTRE
# 12018  Y05763    ELY LOCAL URGENT CARE SERVICE     PRINCESS OF WALES HOSP
#
#                    addr_2           borough         village post_code
# ...

# %%
chem = pd.read_csv('dw-data/chem.csv.gz')
chem.head()
# Out:
#     CHEM SUB                                NAME
# 0  0101010A0                     Alexitol Sodium
# 1  0101010B0                          Almasilate
# 2  0101010C0                 Aluminium Hydroxide
# 3  0101010D0  Aluminium Hydroxide With Magnesium
# 4  0101010E0                        Hydrotalcite

# %% [markdown]
# Now that we've loaded in the data, let's first replicate our results from the `PW` miniproject. Note that we are now working with a larger data set so the answers will be different than in the `PW` miniproject even if the analysis is the same.

# %% [markdown]
# ## Question 1: summary_statistics
#
# In the `PW` miniproject we first calculated the total, mean, standard deviation, and quartile statistics of the `'items'`, `'quantity'`', `'nic'`, and `'act_cost'` fields. To do this we had to write some functions to calculate the statistics and apply the functions to our data structure. The DataFrame has a `describe` method that will calculate most (not all) of these things for us.
#
# Submit the summary statistics to the grader as a list of tuples: [('act_cost', (total, mean, std, q25, median, q75)), ...]

# %%
variables = ['items', 'quantity', 'nic', 'act_cost']
for var in variables:
    (var, (scripts[var].sum(), scripts[var].mean(), scripts[var].std(), scripts[var].quantile(.25), scripts[var].median(), scripts[var].quantile(.75)))

# %%
summary_stats = [(var, (scripts[var].sum(), scripts[var].mean(), scripts[var].std(), scripts[var].quantile(.25), scripts[var].median(), scripts[var].quantile(.75))) for var in variables]

# %%
scripts['items'].quantile(.75)
# Out:
# 6.0

# %%
summary_stats = [('items', (0,) * 6), ('quantity', (0,) * 6), ('nic', (0,) * 6), ('act_cost', (0,) * 6)]

# %%
grader.score.dw__summary_statistics(summary_stats)
# Out:
# ...
# Your score:  0.0
# ...

# %% [markdown]
# ## Question 2: most_common_item
#
# We can also easily compute summary statistics on groups within the data. In the `pw` miniproject we had to explicitly construct the groups based on the values of a particular field. Pandas will handle that for us via the `groupby` method. This process is [detailed in the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/groupby.html).
#
# Use `groupby` to calculate the total number of items dispensed for each `'bnf_name'`. Find the item with the highest total and return the result as `[(bnf_name, total)]`.

# %%
group = scripts.groupby(scripts['bnf_name'])['items'].sum().sort_values(ascending=False)

# %%
group
# Out:
# bnf_name
# Omeprazole_Cap E/C 20mg                     218583
# Paracet_Tab 500mg                           151669
# Aspirin Disper_Tab 75mg                     148591
# Simvastatin_Tab 40mg                        132941
# Amlodipine_Tab 5mg                          128245
#                                              ...
# Quest_Cell Life Antiox Tab                       1
# Quest_Lactase Tab                                1
# Juzo Soft Rib Style Class 1 B/Knee Close         1
# Quetiapine_Oral Soln 12.5mg/5ml                  1
# ReadyWrap Gauntlet Lymph Gmt                     1
# Name: items, Length: 13471, dtype: int64

# %%
most_common_item = [("Omeprazole_Cap E/C 20mg", 218583)]

# %%
grader.score.dw__most_common_item(most_common_item)
# Out:
# ...
# Your score:  1.0
# ...

# %% [markdown]
# ## Question 3: items_by_region
#
# Now let's find the most common item by post code. The post code information is in the `practices` DataFrame, and we'll need to `merge` it into the `scripts` DataFrame. Pandas provides [extensive documentation](https://pandas.pydata.org/pandas-docs/stable/merging.html) with diagrammed examples on different methods and approaches for joining data. The `merge` method is only one of many possible options.
#
# Return your results as a list of tuples `(post code, item name, amount dispensed as % of total)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code. Note some postal codes may have multiple `'bnf_name'` with the same prescription rate for the maximum. In this case, take the alphabetically first `'bnf_name'` (as in the PW miniproject).

# %%
practices['code'].nunique()
# Out:
# 10843

# %%
print(f"Number of practices: {practices.shape[0]}")
print(f"Number of unique practices: {practices['code'].nunique()}")
# Out:
# Number of practices: 12019
# Number of unique practices: 10843

# %%
practices_unique = practices.sort_values('post_code').drop_duplicates(subset='code', keep='first')

# %%
scripts_with_post_code = scripts.merge(practices_unique, left_on='practice', right_on='code', how='left')

# %%
scripts_with_post_code.head(3)
# Out:
#   practice   bnf_code                            bnf_name  items   nic  \
# 0   N85639  0106020C0               Bisacodyl_Tab E/C 5mg      1  0.39
# 1   N85639  0106040M0    Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2   N85639  0301011R0  Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
#
#    act_cost  quantity    code        name                     addr_1  \
# 0      0.47        12  N85639  GP OOH VCH  VICTORIA CENTRAL HOSPITAL
# 1      4.07        30  N85639  GP OOH VCH  VICTORIA CENTRAL HOSPITAL
# 2      1.40         1  N85639  GP OOH VCH  VICTORIA CENTRAL HOSPITAL
#
#       addr_2   borough village post_code
# 0  MILL LANE  WALLASEY     NaN  CH44 5UF
# 1  MILL LANE  WALLASEY     NaN  CH44 5UF
# 2  MILL LANE  WALLASEY     NaN  CH44 5UF

# %%
output = (scripts_with_post_code
          .groupby(['post_code', 'bnf_name'])['items'].sum()
          .reset_index()
          .set_index('post_code'))
output.head()
# Out:
#                                            bnf_name  items
# post_code
# B11 4BW    3m Health Care_Cavilon Durable Barrier C      7
# B11 4BW     3m Health Care_Cavilon No Sting Barrier      2
# B11 4BW        Abasaglar KwikPen_100u/ml 3ml Pf Pen      2
# B11 4BW                                  Abidec_Dps     63
# B11 4BW                  Able Spacer + Sml/Med Mask      1

# %%
total = output.groupby('post_code')['items'].sum()
total.head()
# Out:
# post_code
# B11 4BW    22731
# B12 9LP    17073
# B18 7AL    20508
# B21 9RY    31027
# B23 6DJ    28011
# Name: items, dtype: int64

# %%
output['total'] = total
output.head()
# Out:
#                                            bnf_name  items  total
# post_code
# B11 4BW    3m Health Care_Cavilon Durable Barrier C      7  22731
# B11 4BW     3m Health Care_Cavilon No Sting Barrier      2  22731
# B11 4BW        Abasaglar KwikPen_100u/ml 3ml Pf Pen      2  22731
# B11 4BW                                  Abidec_Dps     63  22731
# B11 4BW                  Able Spacer + Sml/Med Mask      1  22731

# %%
output['ratio'] = output['items'] / output['total']

# %%
output.head()
# Out:
#                                            bnf_name  items  total     ratio
# post_code
# B11 4BW    3m Health Care_Cavilon Durable Barrier C      7  22731  0.000308
# B11 4BW     3m Health Care_Cavilon No Sting Barrier      2  22731  0.000088
# B11 4BW        Abasaglar KwikPen_100u/ml 3ml Pf Pen      2  22731  0.000088
# B11 4BW                                  Abidec_Dps     63  22731  0.002772
# B11 4BW                  Able Spacer + Sml/Med Mask      1  22731  0.000044

# %%
result = output.groupby('post_code').apply(lambda df: df.sort_values('ratio', ascending=False).iloc[0])

# %%
items_by_region = result.reset_index()[['post_code', 'bnf_name', 'ratio']].sort_values('post_code').head(100)

# %%
items_by_region.head()
# Out:
#   post_code                            bnf_name     ratio
# 0   B11 4BW  Salbutamol_Inha 100mcg (200 D) CFF  0.031059
# 1   B12 9LP                   Paracet_Tab 500mg  0.024893
# 2   B18 7AL  Salbutamol_Inha 100mcg (200 D) CFF  0.027111
# 3   B21 9RY             Metformin HCl_Tab 500mg  0.033294
# 4   B23 6DJ    Lansoprazole_Cap 30mg (E/C Gran)  0.021384

# %%
#items_by_region = [("B11 4BW", "Salbutamol_Inha 100mcg (200 D) CFF", 0.0310589063)] * 100

# %%
grader.score.dw__items_by_region(items_by_region)
# Out:
# ...
# Your score:  1.0
# ...

# %% [markdown]
# ## Question 4: script_anomalies
#
# Drug abuse is a source of human and monetary costs in health care. A first step in identifying practitioners that enable drug abuse is to look for practices where commonly abused drugs are prescribed unusually often. Let's try to find practices that prescribe an unusually high amount of opioids. The opioids we'll look for are given in the list below.

# %%
opioids = ['morphine', 'oxycodone', 'methadone', 'fentanyl', 'pethidine', 'buprenorphine', 'propoxyphene', 'codeine']

# %% [markdown]
# These are generic names for drugs, not brand names. Generic drug names can be found using the `'bnf_code'` field in `scripts` along with the `chem` table.. Use the list of opioids provided above along with these fields to make a new field in the `scripts` data that flags whether the row corresponds with a opioid prescription.

# %%
scripts.head()
# Out:
#   practice   bnf_code                              bnf_name  items   nic  \
# 0   N85639  0106020C0                 Bisacodyl_Tab E/C 5mg      1  0.39
# 1   N85639  0106040M0      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2   N85639  0301011R0    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 3   N85639  0304010G0  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 4   N85639  0401020K0                      Diazepam_Tab 2mg      1  0.16
#
#    act_cost  quantity
# 0      0.47        12
# 1      4.07        30
# 2      1.40         1
# 3      2.44       150
# 4      0.26         6

# %%
chem.head()
# Out:
#     CHEM SUB                                NAME
# 0  0101010A0                     Alexitol Sodium
# 1  0101010B0                          Almasilate
# 2  0101010C0                 Aluminium Hydroxide
# 3  0101010D0  Aluminium Hydroxide With Magnesium
# 4  0101010E0                        Hydrotalcite

# %%
chem.shape
# Out:
# (3487, 2)

# %%
chem['CHEM SUB'].nunique()
# Out:
# 3481

# %%
chem = chem.sort_values('CHEM SUB').drop_duplicates(subset='CHEM SUB', keep='first')
chem.shape
# Out:
# (3481, 2)

# %%
chem.head()
# Out:
#      CHEM SUB                                NAME
# 18  010101000    Other Antacid & Simeticone Preps
# 0   0101010A0                     Alexitol Sodium
# 1   0101010B0                          Almasilate
# 2   0101010C0                 Aluminium Hydroxide
# 3   0101010D0  Aluminium Hydroxide With Magnesium

# %%
#Join chem and scripts together
#Flag prescriptions that are opiods based upon their value of name

# %%
scripts_and_chem = scripts.merge(chem, left_on='bnf_code', right_on='CHEM SUB', how='inner')

# %%
scripts_and_chem.head()
# Out:
#   practice   bnf_code               bnf_name  items    nic  act_cost  \
# 0   N85639  0106020C0  Bisacodyl_Tab E/C 5mg      1   0.39      0.47
# 1   N81013  0106020C0  Bisacodyl_Tab E/C 5mg     19  28.10     28.14
# 2   N81029  0106020C0  Bisacodyl_Tab E/C 5mg     50  67.73     67.51
# 3   N81029  0106020C0  Bisacodyl_Suppos 10mg      1   1.77      1.75
# 4   N81029  0106020C0       Dulcolax_Tab 5mg      1   3.78      3.61
#
#    quantity   CHEM SUB       NAME
# 0        12  0106020C0  Bisacodyl
# 1       860  0106020C0  Bisacodyl
# 2      2074  0106020C0  Bisacodyl
# 3         6  0106020C0  Bisacodyl
# 4        56  0106020C0  Bisacodyl

# %%
#checking whether any of the strings in opiods lists appears in the string in column names
scripts_and_chem.loc[0, 'NAME']
# Out:
# 'Bisacodyl'

# %%
any([opioid in scripts and scripts_and_chem.loc[0, 'NAME'] for opioid in opioids])
# Out:
# False

# %%
scripts_and_chem['NAME'].isnull().sum()
# Out:
# 0

# %%
scripts_and_chem.shape
# Out:
# (854444, 9)

# %%
scripts_and_chem['NAME'].apply(lambda name: any([opioid in name for opioid in opioids]))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 854439    False
# 854440    False
# 854441    False
# 854442    False
# 854443    False
# Name: NAME, Length: 854444, dtype: bool

# %%
scripts_and_chem['NAME'].str.lower().isin(opioids).sum()
# Out:
# 8668

# %%
scripts_and_chem['is_opioid'] = scripts_and_chem['NAME'].str.lower().isin(opioids)

# %%
scripts_and_chem['is_opioid'].sum()
# Out:
# 8668

# %%
scripts_and_chem[scripts_and_chem['is_opioid']]
# Out:
#        practice   bnf_code                               bnf_name  items  \
# 359222   N81013  0407020A0    Fentanyl_Transdermal Patch 12mcg/hr      1
# 359223   N81013  0407020A0  Fentanyl_Transdermal Patch 37.5mcg/hr      2
# 359224   N81013  0407020A0    Durogesic DTrans_T/Derm Patch 25mcg      1
# 359225   N81013  0407020A0    Durogesic DTrans_T/Derm Patch 12mcg      1
# 359226   N81013  0407020A0                Matrifen_Patch 12mcg/hr      3
# ...         ...        ...                                    ...    ...
# 367885   H81615  0407020B0      BuTrans_Transdermal Patch 5mcg/hr      4
# 367886   H81615  0407020B0     BuTrans_Transdermal Patch 10mcg/hr      5
# 367887   H81615  0407020B0     BuTrans_Transdermal Patch 15mcg/hr      1
# 367888   H81615  0407020B0        Butec_Transdermal Patch 5mcg/hr      1
# 367889   H81615  0407020B0       Butec_Transdermal Patch 10mcg/hr      1
#
#            nic  act_cost  quantity   CHEM SUB           NAME  is_opioid
# ...

# %%
#scripts_and_chem['NAME'].str.lower().isin(opioids)

# %%
#chem['is_opioid'] = scripts_and_chem['NAME'].str.lower().isin(opioids)
#scripts_and_chem = scripts.merge(chem[['CHEM SUB', 'is_opioid']], left_on='bnf_code', right_on='CHEM SUB', how='inner')

# %%
#chem['NAME'].str.lower().isin(opioids).sum()

# %%
#scripts_and_chem.head()

# %%
#scripts_and_chem['is_opioid'].value_counts()

# %%
#scripts_and_chem['NAME'].apply(lambda name: any(opioid in name for opioid in opioids))

# %% [markdown]
# Now for each practice calculate the proportion of its prescriptions containing opioids.
#
# **Hint:** Consider the following list: `[0, 1, 1, 0, 0, 0]`. What proportion of the entries are 1s? What is the mean value?

# %%
scripts_and_chem.groupby('practice')['is_opioid'].mean()
# Out:
# practice
# A81005    0.007109
# A81007    0.013147
# A81011    0.014749
# A81012    0.010239
# A81017    0.014658
#             ...
# Y05570    0.000000
# Y05583    0.000000
# Y05597    0.000000
# Y05660    0.000000
# Y05670    0.000000
# Name: is_opioid, Length: 850, dtype: float64

# %%
opioids_per_practice = scripts_and_chem.groupby('practice')['is_opioid'].mean()

# %%
opioids_per_practice.head()
# Out:
# practice
# A81005    0.007109
# A81007    0.013147
# A81011    0.014749
# A81012    0.010239
# A81017    0.014658
# Name: is_opioid, dtype: float64

# %% [markdown]
# How do these proportions compare to the overall opioid prescription rate? Subtract off the proportion of all prescriptions that are opioids from each practice's proportion.

# %%
relative_opioids_per_practice = opioids_per_practice - scripts_and_chem['is_opioid'].mean()

# %%
relative_opioids_per_practice
# Out:
# practice
# A81005   -0.003036
# A81007    0.003002
# A81011    0.004605
# A81012    0.000094
# A81017    0.004513
#             ...
# Y05570   -0.010145
# Y05583   -0.010145
# Y05597   -0.010145
# Y05660   -0.010145
# Y05670   -0.010145
# Name: is_opioid, Length: 850, dtype: float64

# %% [markdown]
# Now that we know the difference between each practice's opioid prescription rate and the overall rate, we can identify which practices prescribe opioids at above average or below average rates. However, are the differences from the overall rate important or just random deviations? In other words, are the differences from the overall rate big or small?
#
# To answer this question we have to quantify the difference we would typically expect between a given practice's opioid prescription rate and the overall rate. This quantity is called the **standard error**, and is related to the **standard deviation**, $\sigma$. The standard error in this case is
#
# $$ \frac{\sigma}{\sqrt{n}} $$
#
# where $n$ is the number of prescriptions each practice made. Calculate the standard error for each practice. Then divide `relative_opioids_per_practice` by the standard errors. We'll call the final result `opioid_scores`.

# %%
#Denoinator is standard deviation of global opioid rate divided by number of prescriptions per practice
#need to determine the number of prescriptions per practice

# %%
scripts_and_chem.groupby('practice')['is_opioid'].count()
# Out:
# practice
# A81005    1266
# A81007    1217
# A81011    1356
# A81012    1172
# A81017    1842
#           ...
# Y05570      22
# Y05583      28
# Y05597      18
# Y05660     314
# Y05670      11
# Name: is_opioid, Length: 850, dtype: int64

# %%
scripts_and_chem['practice'].value_counts()
# Out:
# N83028    2402
# L83100    2239
# D81043    2099
# B81008    2081
# G81013    2004
#           ...
# Y03179       1
# Y01174       1
# Y03010       1
# Y05366       1
# Y03472       1
# Name: practice, Length: 850, dtype: int64

# %%
standard_error_per_practice = scripts_and_chem['is_opioid'].std() / scripts_and_chem['practice'].value_counts() ** 0.5
opioid_scores = relative_opioids_per_practice / standard_error_per_practice

# %%
standard_error_per_practice.head()
# Out:
# N83028    0.002045
# L83100    0.002118
# D81043    0.002187
# B81008    0.002197
# G81013    0.002238
# Name: practice, dtype: float64

# %%
opioid_scores.name = "z-score"

# %% [markdown]
# The quantity we have calculated in `opioid_scores` is called a **z-score**:
#
# $$ \frac{\bar{X} - \mu}{\sqrt{\sigma^2/n}} $$
#
# Here $\bar{X}$ corresponds with the proportion for each practice, $\mu$ corresponds with the proportion across all practices, $\sigma^2$ corresponds with the variance of the proportion across all practices, and $n$ is the number of prescriptions made by each practice. Notice $\bar{X}$ and $n$ will be different for each practice, while $\mu$ and $\sigma$ are determined across all prescriptions, and so are the same for every z-score. The z-score is a useful statistical tool used for hypothesis testing, finding outliers, and comparing data about different types of objects or events.
#
# Now that we've calculated this statistic, take the 100 practices with the largest z-score. Return your result as a list of tuples in the form `(practice_name, z-score, number_of_scripts)`. Sort your tuples by z-score in descending order. Note that some practice codes will correspond with multiple names. In this case, use the first match when sorting names alphabetically.

# %%
unique_practices = practices.sort_values('name').drop_duplicates(subset='code', keep='first')
#anomalies = [("NATIONAL ENHANCED SERVICE", 11.6958178629, 7)] * 100

# %%
unique_practices.head()
# Out:
#          code                                      name  \
# 7011   P87657  (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI
# 10921  Y05381        0-19 EAST CHESHIRE HEALTH VISITORS
# 11983  Y04082     0-19 PUBLIC HEALTH SERVICE HARTLEPOOL
# 7572   Y00364                             1 TO 1 CENTRE
# 6835   P87652        1/LOWER BROUGHTON MEDICAL PRACTICE
#
#                          addr_1               addr_2              borough  \
# 7011    SALFORD CARE CTR(IRLAM)   125 LIVERPOOL ROAD                IRLAM
# 10921            SALINAE CLINIC         LEWIN STREET           MIDDLEWICH
# 11983  CHATHAM CHILDRENS CENTRE      29 CHATHAM ROAD           HARTLEPOOL
# 7572            BRENKLEY AVENUE            SHIREMOOR  NEWCASTLE UPON TYNE
# 6835   LOWER BROUGHTON HTH.CTR.  GREAT CLOWES STREET              SALFORD
#
#           village post_code
# 7011   MANCHESTER   M44 6DP
# 10921    CHESHIRE  CW10 9FG
# 11983         NaN  TS24 8QG
# 7572          NaN  NE27 0PR
# 6835          NaN    M7 1RD

# %%
unique_practices = unique_practices.merge(opioid_scores, left_on='code', right_index=True)

# %%
scripts.groupby('practice')['practice'].count()
# Out:
# practice
# A81005    1507
# A81007    1454
# A81011    1568
# A81012    1332
# A81017    2150
#           ...
# Y05570      22
# Y05583      28
# Y05597      18
# Y05660     347
# Y05670      12
# Name: practice, Length: 856, dtype: int64

# %%
scripts['practice'].count()
# Out:
# 973193

# %%
x = scripts['practice'].value_counts()
x
# Out:
# N83028    2844
# L83100    2797
# D81043    2459
# B81008    2396
# B81026    2347
#           ...
# Y03010       1
# Y01174       1
# C85617       1
# Y03472       1
# Y03179       1
# Name: practice, Length: 856, dtype: int64

# %%
unique_practices['count'] = scripts.groupby('practice')['practice'].count()

# %%
unique_practices['count']
# Out:
# 6835    NaN
# 6484    NaN
# 6907    NaN
# 7201    NaN
# 6493    NaN
#          ..
# 9388    NaN
# 6102    NaN
# 11397   NaN
# 5340    NaN
# 6613    NaN
# Name: count, Length: 850, dtype: float64

# %%
unique_practices['count'] = scripts['practice'].value_counts()
unique_practices.sort_values('z-score', ascending=False)
# Out:
#          code                                     name  \
# 7453   G81703                   H&R P C SPECIAL SCHEME
# 474    B81069  PRACTICE 3  MEDICAL CENTRE  BRIDLINGTON
# 528    B82001                        FALSGRAVE SURGERY
# 7953   Y01852                NATIONAL ENHANCED SERVICE
# 1363   C85008               HOYLAND FIRST PMS PRACTICE
# ...       ...                                      ...
# 6472   P86619                      DR GHAFOOR & ABBASI
# 11193  N85003                   ALLPORT MEDICAL CENTRE
# 5435   M85715            SOHO ROAD PRIMARY CARE CENTRE
# 7166   M91659               BRACE STREET HEALTH CENTRE
# 660    B83058            THE AVICENNA MEDICAL PRACTICE
#
#                           addr_1                   addr_2  \
# 7453    STATION PLAZA HEALTH CTR         STATION APPROACH
# 474           THE MEDICAL CENTRE           STATION AVENUE
# 528            FALSGRAVE SURGERY   LAWRENCE HOUSE MED CTR
# 7953             NYE BEVAN HOUSE             MACLURE ROAD
# ...

# %%
unique_practices['count']
# Out:
# 6835    NaN
# 6484    NaN
# 6907    NaN
# 7201    NaN
# 6493    NaN
#          ..
# 9388    NaN
# 6102    NaN
# 11397   NaN
# 5340    NaN
# 6613    NaN
# Name: count, Length: 850, dtype: float64

# %%
unique_practices.head()
# Out:
#         code                                name                     addr_1  \
# 6835  P87652  1/LOWER BROUGHTON MEDICAL PRACTICE   LOWER BROUGHTON HTH.CTR.
# 6484  P87020       2/ST ANDREWS MEDICAL PRACTICE  ST.ANDREWS MEDICAL CENTRE
# 6907  P87654  3/LOWER BROUGHTON MEDICAL PRACTICE   LOWER BROUGHTON HTH.CTR.
# 7201  P87659         3/ST ANDREWS MEDICAL CENTRE  ST.ANDREWS MEDICAL CENTRE
# 6493  P87036  4/LOWER BROUGHTON MEDICAL PRACTICE   LOWER BROUGHTON HTH.CTR.
#
#                          addr_2     borough     village post_code   z-score  \
# 6835        GREAT CLOWES STREET     SALFORD         NaN    M7 1RD -0.256762
# 6484  30 RUSSELL STREET  ECCLES  MANCHESTER         NaN   M30 0NU -0.705053
# 6907        GREAT CLOWES STREET     SALFORD         NaN    M7 1RD -0.425940
# 7201  30 RUSSELL STREET  ECCLES  MANCHESTER         NaN   M30 0NU  0.989859
# 6493        GREAT CLOWES STREET     SALFORD  MANCHESTER    M7 1RD  0.535444
#
#       count
# 6835    NaN
# 6484    NaN
# ...

# %% [markdown]
# ## FRESH START

# %%
col_names=[ 'code', 'name', 'addr_1', 'addr_2', 'borough', 'village', 'post_code']
practices = pd.read_csv('dw-data/practices.csv.gz')
practices.columns = col_names
practices
# Out:
#          code                             name                     addr_1  \
# 0      A81002       QUEENS PARK MEDICAL CENTRE    QUEENS PARK MEDICAL CTR
# 1      A81003        VICTORIA MEDICAL PRACTICE          THE HEALTH CENTRE
# 2      A81004           WOODLANDS ROAD SURGERY           6 WOODLANDS ROAD
# 3      A81005               SPRINGWOOD SURGERY         SPRINGWOOD SURGERY
# 4      A81006  TENNANT STREET MEDICAL PRACTICE       TENNANT ST MED PRACT
# ...       ...                              ...                        ...
# 12014  Y05752             MALVERN FRAILTY UNIT     MALVERN COMM. HOSPITAL
# 12015  Y05757             VC WEST LANCS HC-UCC       ORMSKIRK DG HOSPITAL
# 12016  Y05758              VC SKELMERSDALE UCC  CONCOURSE SHOPPING CENTRE
# 12017  Y05762           WEST MERTON ACCESS HUB   THE NELSON HEALTH CENTRE
# 12018  Y05763    ELY LOCAL URGENT CARE SERVICE     PRINCESS OF WALES HOSP
#
#                    addr_2           borough         village post_code
# ...

# %%
scripts.head()
# Out:
#   practice   bnf_code                              bnf_name  items   nic  \
# 0   N85639  0106020C0                 Bisacodyl_Tab E/C 5mg      1  0.39
# 1   N85639  0106040M0      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2   N85639  0301011R0    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 3   N85639  0304010G0  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 4   N85639  0401020K0                      Diazepam_Tab 2mg      1  0.16
#
#    act_cost  quantity
# 0      0.47        12
# 1      4.07        30
# 2      1.40         1
# 3      2.44       150
# 4      0.26         6

# %%
chem = pd.read_csv('dw-data/chem.csv.gz')
chem = chem.sort_values('CHEM SUB').drop_duplicates(subset='CHEM SUB', keep='first')

# %%
#Flag opioids
opioids = ['morphine', 'oxycodone', 'methadone', 'fentanyl', 'pethidine', 'buprenorphine', 'propoxyphene', 'codeine']
chem['is_opioid'] = chem['NAME'].str.lower().str.contains(r'|'.join(opioids))

# %%
scripts_with_chem = (scripts
                     .merge(chem[['CHEM SUB', 'is_opioid']], left_on='bnf_code', right_on='CHEM SUB', how='left')
                     .fillna(False))

# %%
opioids_per_practice = scripts_with_chem.groupby('practice')['is_opioid'].mean()

# %%
relative_opioids_per_practice = opioids_per_practice - scripts_with_chem['is_opioid'].mean()

# %%
standard_error_per_practice = scripts_with_chem['is_opioid'].std() / (scripts_with_chem['practice'].value_counts() ** 0.5)

# %%
opioid_score = relative_opioids_per_practice / standard_error_per_practice

# %%
opioid_score
# Out:
# A81005   -0.548306
# A81007    1.544557
# A81011    2.291795
# A81012    1.373060
# A81017    0.583168
#             ...
# Y05570    1.391142
# Y05583   -1.019657
# Y05597   -0.817544
# Y05660   -1.278102
# Y05670   -0.667522
# Length: 856, dtype: float64

# %%
unique_practices = practices.sort_values('name').drop_duplicates(subset='code', keep='first')
unique_practices = unique_practices.set_index('code') 
unique_practices['z-score'] = opioid_score
unique_practices['count'] = scripts_with_chem['practice'].value_counts()
unique_practices.head()
# Out:
#                                             name                    addr_1  \
# code
# P87657  (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI   SALFORD CARE CTR(IRLAM)
# Y05381        0-19 EAST CHESHIRE HEALTH VISITORS            SALINAE CLINIC
# Y04082     0-19 PUBLIC HEALTH SERVICE HARTLEPOOL  CHATHAM CHILDRENS CENTRE
# Y00364                             1 TO 1 CENTRE           BRENKLEY AVENUE
# P87652        1/LOWER BROUGHTON MEDICAL PRACTICE  LOWER BROUGHTON HTH.CTR.
#
#                      addr_2              borough     village post_code  \
# code
# P87657   125 LIVERPOOL ROAD                IRLAM  MANCHESTER   M44 6DP
# Y05381         LEWIN STREET           MIDDLEWICH    CHESHIRE  CW10 9FG
# Y04082      29 CHATHAM ROAD           HARTLEPOOL         NaN  TS24 8QG
# Y00364            SHIREMOOR  NEWCASTLE UPON TYNE         NaN  NE27 0PR
# P87652  GREAT CLOWES STREET              SALFORD         NaN    M7 1RD
#
#          z-score   count
# code
# P87657       NaN     NaN
# ...

# %%
unique_practices.sort_values('z-score', ascending=False).head(100)
# Out:
#                                    name                     addr_1  \
# code
# Y01852        NATIONAL ENHANCED SERVICE            NYE BEVAN HOUSE
# Y03006         OUTREACH SERVICE NH / RH  PCC 69 CHURCH STREET WEST
# Y03668  BRISDOC HEALTHCARE SERVICES OOH    KNOWLE WEST HEALTH PARK
# G81703           H&R P C SPECIAL SCHEME   STATION PLAZA HEALTH CTR
# Y04997                   HMR BARDOC OOH  MOORGATE PRIMARY CARE CTR
# ...                                 ...                        ...
# D81024                    THOMAS WALKER      THOMAS WALKER SURGERY
# A81033        OAKFIELD MEDICAL PRACTICE     OAKFIELDS MED PRACTICE
# P81684          DR DP CHARLES' PRACTICE         HARROWSIDE SURGERY
# N81121        NORTHGATE VILLAGE SURGERY           FOUNTAINS HEALTH
# P81099      DR THM MACKENZIE & PARTNERS   HASLINGDEN HEALTH CENTRE
#
#                            addr_2         borough       village post_code  \
# code
# ...

# %%
results = unique_practices[['name', 'z-score', 'count']].nlargest(100, 'z-score')

# %%
results.head()
# Out:
#                                    name    z-score  count
# code
# Y01852        NATIONAL ENHANCED SERVICE  11.695818    7.0
# Y03006         OUTREACH SERVICE NH / RH   7.339043    2.0
# Y03668  BRISDOC HEALTHCARE SERVICES OOH   6.150582   60.0
# G81703           H&R P C SPECIAL SCHEME   5.123032   36.0
# Y04997                   HMR BARDOC OOH   4.958866  321.0

# %%
grader.score.dw__script_anomalies(results)
# Out:
# ...
# Error!
# You have been rate limited for exceeding the limit of 3 per 1 minute.
# Please slow down your submission rate.
# ...

# %% [markdown]
# ## Question 5: script_growth
#
# Another way to identify anomalies is by comparing current data to historical data. In the case of identifying sites of drug abuse, we might compare a practice's current rate of opioid prescription to their rate 5 or 10 years ago. Unless the nature of the practice has changed, the profile of drugs they prescribe should be relatively stable. We might also want to identify trends through time for business reasons, identifying drugs that are gaining market share. That's what we'll do in this question.
#
# We'll load in beneficiary data from 6 months earlier, June 2016, and calculate the percent growth in prescription rate from June 2016 to January 2017 for each `bnf_name`. We'll return the 50 items with largest growth and the 50 items with the largest shrinkage (i.e. negative percent growth) as a list of tuples sorted by growth rate in descending order in the format `(script_name, growth_rate, raw_2016_count)`. You'll notice that many of the 50 fastest growing items have low counts of prescriptions in 2016. Filter out any items that were prescribed less than 50 times.

# %%
scripts16 = pd.read_csv('dw-data/201606scripts_sample.csv.gz')

# %%
#Calculate (X_1 - X_0) / X_0 = (X_1 / X_0 -1)

# %%
scripts16['bnf_name'].value_counts()
# Out:
# GlucoRX FinePoint Needles Pen Inj Screw     1532
# 3m Health Care_Cavilon Durable Barrier C     825
# Fluclox Sod_Cap 500mg                        796
# Amoxicillin_Cap 500mg                        790
# Prednisolone_Tab 5mg                         786
#                                             ...
# Heparin Sod_Inj 1 000u/ml 1ml Amp              1
# Welland_Lge Post-Op Drnbl Ileo Bag + S/B       1
# Jade_Cone Top Rubb Curved Lge                  1
# Sterogyl_Oral Soln 100 000u/5ml                1
# Vanilla Blush_Supp/Vest Unisex Blk XXLge       1
# Name: bnf_name, Length: 13540, dtype: int64

# %%
scripts['bnf_name'].value_counts()
# Out:
# GlucoRX FinePoint Needles Pen Inj Screw     1718
# 3m Health Care_Cavilon Durable Barrier C     816
# Prednisolone_Tab 5mg                         785
# Fluclox Sod_Cap 500mg                        783
# Amoxicillin_Cap 500mg                        777
#                                             ...
# Ultrasun_Extreme Lot SPF 50+                   1
# M.Sauer_Comfort Sheath Med (Diam 28mm)         1
# Scanpor 1.25cm x 10m Surg Adh Tape Perm        1
# Renasys G Gauze Dress Kit + Soft Port Sm       1
# Neon Verifine Needles Pen Inj Screw On 1       1
# Name: bnf_name, Length: 13471, dtype: int64

# %%
pct_growth = scripts['bnf_name'].value_counts() / scripts16['bnf_name'].value_counts() - 1
pct_growth.name = 'growth_rate'

# %%
#Method chaining
result = (pct_growth.to_frame()
          .assign(raw_count = scripts16['bnf_name'].value_counts())
          .query('raw_count > = 50')
          .dropna()
          .sort_values('growth_rate', ascending=False)
          .reset_index()
          .rename({'index':'bnf_name'}, axis=1))

# %%
#result['raw_count'] = raw_count = scripts16['bnf_name'].value_counts()

# %%
#result = (result
#          .sort_values('pct_growth', ascending=False)
#          .query('raw_count > 50')
#          .dropna()
#          .reset_index())
#result.head()

# %%
script_growth = pd.concat([result.head(50), result.tail(50)])
script_growth
# Out:
#                                       bnf_name  growth_rate  raw_count
# 0              Butec_Transdermal Patch 5mcg/hr     3.467742       62.0
# 1             Butec_Transdermal Patch 10mcg/hr     3.000000       69.0
# 2     Fostair NEXThaler_Inh 200mcg/6mcg (120D)     1.430233       86.0
# 3        Pneumococcal_Vac 0.5ml Vl (23 Valent)     1.269430      193.0
# 4     Spiolto Respimat_Inha2.5/2.5mcg(60D)+Dev     1.269231       52.0
# ...                                        ...          ...        ...
# 3480        Hydroxyzine HCl_Oral Soln 10mg/5ml    -0.914894       94.0
# 3481                               Ovysmen_Tab    -0.925373       67.0
# 3482                          Climaval_Tab 1mg    -0.926471      136.0
# 3483                              Climesse_Tab    -0.942029       69.0
# 3484                      Polyalc_Eye Dps 1.4%    -0.996324      272.0
#
# [100 rows x 3 columns]

# %%
script_growth_ans = script_growth[['bnf_name', 'growth_rate', 'raw_count']]

# %%
script_growth = [("Butec_Transdermal Patch 5mcg\/hr", 3.4677419355, 62.0)] * 100

# %%
grader.score.dw__script_growth(script_growth_ans)
# Out:
# ...
# Error!
# You have been rate limited for exceeding the limit of 3 per 1 minute.
# Please slow down your submission rate.
# ...

# %% [markdown]
# ## Question 6: rare_scripts
#
# Does a practice's prescription costs originate from routine care or from reliance on rarely prescribed treatments? Commonplace treatments can carry lower costs than rare treatments because of efficiencies in large-scale production. While some specialist practices can't help but avoid prescribing rare medicines because there are no alternatives, some practices may be prescribing a unnecessary amount of brand-name products when generics are available. Let's identify practices whose costs disproportionately originate from rarely prescribed items.
#
# First we have to identify which `'bnf_code'` are rare. To do this, find the probability $p$ of a prescription having a particular `'bnf_code'` if the `'bnf_code'` was randomly chosen from the unique options in the beneficiary data. We will call a `'bnf_code'` rare if it is prescribed at a rate less than $0.1p$.

# %%
# Plan of Attack:
# 1. Find the uniform probability
# 2. Find frequencies for each drug(bnf_code) = number of prescriptions of that kind / number of prescriptions
# 3. Flag BNF codes that are deemed rare

# %%
p = 1 / scripts['bnf_code'].nunique()   # or len(scripts['bnf_code'].umique())
rates = scripts['bnf_code'].value_counts() / len(scripts)
rare_codes = rates < 0.1 * p
scripts = scripts.set_index('bnf_code')
scripts['rare'] = rare_codes

# %%
scripts.head()
# Out:
#           practice                              bnf_name  items   nic  \
# bnf_code
# 0106020C0   N85639                 Bisacodyl_Tab E/C 5mg      1  0.39
# 0106040M0   N85639      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 0301011R0   N85639    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 0304010G0   N85639  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 0401020K0   N85639                      Diazepam_Tab 2mg      1  0.16
#
#            act_cost  quantity   rare
# bnf_code
# 0106020C0      0.47        12  False
# 0106040M0      4.07        30  False
# 0301011R0      1.40         1  False
# 0304010G0      2.44       150  False
# 0401020K0      0.26         6  False

# %%
print(f"Number of rare prescriptions:{scripts['rare'].sum()}")
# Out:
# Number of rare prescriptions:11570

# %%
np.log(rates).hist(bins=40)

# %% [markdown]
# Now for each practice, calculate the proportion of costs that originate from prescription of rare treatments (i.e. rare `'bnf_code'`). Use the `'act_cost'` field for this calculation.

# %%
# Filter to only include the rare prescriptions
# Group by practice
# Aggregate to calculate the sum of actual cost

rare_cost_total = scripts.query("rare==True").groupby('practice')['act_cost'].sum()
all_cost_total = scripts.groupby('practice')['act_cost'].sum()

# %%
rare_cost_prop = (rare_cost_total / all_cost_total)
rare_cost_prop.isnull().sum()
# Out:
# 90

# %%
set(all_cost_total.index) - set(rare_cost_total.index)
# Out:
# {'A89621',
#  'B81685',
#  'C85617',
#  'G81703',
#  'N83612',
#  'N85639',
#  'N85647',
#  'P81793',
#  'Y00016',
#  'Y00043',
#  'Y00234',
#  'Y00418',
#  'Y00459',
#  'Y00581',
#  'Y00599',
#  'Y00620',
#  'Y00675',
#  'Y00828',
#  'Y00860',
#  'Y00908',
#  'Y00934',
#  'Y00992',
#  'Y01130',
#  'Y01174',
#  'Y01262',
#  'Y01634',
#  'Y01667',
#  'Y01716',
#  'Y01852',
#  'Y01894',
#  'Y01943',
#  'Y02318',
#  'Y02496',
#  'Y02532',
#  'Y02533',
#  'Y02696',
#  'Y02851',
#  'Y02947',
#  'Y03006',
#  'Y03010',
#  'Y03077',
#  'Y03179',
#  'Y03408',
#  'Y03514',
#  'Y03640',
#  'Y03668',
#  'Y03712',
#  'Y03780',
#  'Y03839',
#  'Y03860',
#  'Y03863',
#  'Y04030',
#  'Y04080',
#  'Y04147',
#  'Y04168',
#  'Y04354',
#  'Y04426',
#  'Y04495',
#  'Y04510',
#  'Y04531',
#  'Y04588',
#  'Y04603',
#  'Y04657',
#  'Y04681',
#  'Y04692',
#  'Y04831',
#  'Y04913',
#  'Y04921',
#  'Y04922',
#  'Y04923',
#  'Y04972',
#  'Y05131',
#  'Y05192',
#  'Y05233',
#  'Y05269',
#  'Y05274',
# ...

# %%
scripts.query('practice == "Y05366"')
# Out:
#           practice                                bnf_name  items  nic  \
# bnf_code
# 0301011R0   Y05366  Salbutamol_Inha B/A 100mcg (200 D) CFF      1  6.3
#
#            act_cost  quantity   rare
# bnf_code
# 0301011R0      5.84         1  False

# %% [markdown]
# Now we will calculate a z-score for each practice based on this proportion.
# First take the difference of `rare_cost_prop` and the proportion of costs originating from rare treatments across all practices.

# %%
relative_rare_cost_prop = rare_cost_prop - scripts.query('rare == True')['act_cost'].sum() / scripts['act_cost'].sum()

# %% [markdown]
# Now we will estimate the standard errors (i.e. the denominator of the z-score) by simply taking the standard deviation of this difference.

# %%
standard_errors = relative_rare_cost_prop.std()

# %% [markdown]
# Finally compute the z-scores. Return the practices with the top 100 z-scores in the form `(post_code, practice_name, z-score)`. Note that some practice codes will correspond with multiple names. In this case, use the first match when sorting names alphabetically.

# %%
rare_scores = relative_rare_cost_prop / standard_errors

# %%
rare_scores.hist(bins=40)

# %%
unique_practices['rare_scores'] = rare_scores

rare_scripts = (unique_practices
 .sort_values('rare_scores', ascending=False)
 .reset_index()
 .loc[:, ['code', 'name', 'rare_scores']]
 .head(100))

# %%
rare_scripts.head()
# Out:
#      code                               name  rare_scores
# 0  Y03472           CONSULTANT DIABETES TEAM    15.488407
# 1  Y05320     DMC COMMUNITY DERMATOLOGY RBWF    14.408360
# 2  Y04404  OUTPATIENTS JUBILEE HEALTH CENTRE     7.183052
# 3  Y03484   DMC COMMUNITY DERMATOLOGY CLINIC     6.940271
# 4  Y04424                     DMC HEALTHCARE     6.513022

# %%
#rare_scripts = [("Y03472", "CONSULTANT DIABETES TEAM", 16.2626871247)] * 100

# %%
grader.score.dw__rare_scripts(rare_scripts)
# Out:
# ...
# Your score:  1.0
# ...

# %% [markdown]
# *Copyright &copy; 2020 The Data Incubator.  All rights reserved.*
